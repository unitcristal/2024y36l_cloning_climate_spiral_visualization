# %%
# 2024Y 38L updated

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = "ignore")

# %%
# tables of global and hemispheric monthly means and zonal annual means

df = pd.read_csv("GLB.Ts+dSST.csv", header =1)
df = df.iloc[:, :13]

# %%
# df.info()

# %%
to_convert = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

df = df.replace({'***':pd.NA})
df[to_convert] = df[to_convert].apply(pd.to_numeric, errors='coerce')
df = df.fillna('***')
df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.20 -0.25 -0.09 -0.16 -0.09 -0.21  -0.2  -0.1 -0.15 -0.23 -0.23
# 1    1881 -0.20 -0.15  0.02  0.04  0.07 -0.19  0.01 -0.04 -0.16 -0.22 -0.19
# 2    1882  0.16  0.14  0.05 -0.16 -0.14 -0.22 -0.16 -0.08 -0.15 -0.23 -0.17
# 3    1883 -0.29 -0.36 -0.12 -0.18 -0.17 -0.07 -0.07 -0.14 -0.22 -0.11 -0.24
# 4    1884 -0.13 -0.08 -0.36  -0.4 -0.33 -0.34  -0.3 -0.27 -0.27 -0.25 -0.33
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 141  2021  0.81  0.64  0.89  0.75  0.79  0.84  0.91  0.81  0.92  0.98  0.92
# 142  2022  0.91  0.89  1.04  0.83  0.84  0.92  0.94  0.94  0.88  0.96  0.73
# 143  2023  0.87  0.97  1.23  0.99  0.94  1.08  1.19  1.19  1.48  1.34  1.41
# 144  2024  1.24  1.43  1.39  1.31  1.16  1.24   1.2   1.3  1.23  1.33  1.29
# 145  2025  1.36   ***   ***   ***   ***   ***   ***   ***   ***   ***   ***
#
#       Dec
# 0   -0.18
# 1   -0.07
# 2   -0.36
# 3   -0.11
# 4   -0.31
# ..    ...
# 141  0.87
# 142   0.8
# 143  1.36
# 144  1.26
# 145   ***
#
# [146 rows x 13 columns]

# %%
# df.to_csv("glb_temp.csv")

# %%
temp = pd.read_csv('glb_temp.csv')
temp.head(1)
# Out:
#    Unnamed: 0  Year  Jan    Feb    Mar    Apr    May    Jun   Jul   Aug  \
# 0           0  1880 -0.2  -0.25  -0.09  -0.16  -0.09  -0.21  -0.2  -0.1
#
#      Sep    Oct    Nov    Dec
# 0  -0.15  -0.23  -0.23  -0.18

# %%
df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.20 -0.25 -0.09 -0.16 -0.09 -0.21  -0.2  -0.1 -0.15 -0.23 -0.23
# 1    1881 -0.20 -0.15  0.02  0.04  0.07 -0.19  0.01 -0.04 -0.16 -0.22 -0.19
# 2    1882  0.16  0.14  0.05 -0.16 -0.14 -0.22 -0.16 -0.08 -0.15 -0.23 -0.17
# 3    1883 -0.29 -0.36 -0.12 -0.18 -0.17 -0.07 -0.07 -0.14 -0.22 -0.11 -0.24
# 4    1884 -0.13 -0.08 -0.36  -0.4 -0.33 -0.34  -0.3 -0.27 -0.27 -0.25 -0.33
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 141  2021  0.81  0.64  0.89  0.75  0.79  0.84  0.91  0.81  0.92  0.98  0.92
# 142  2022  0.91  0.89  1.04  0.83  0.84  0.92  0.94  0.94  0.88  0.96  0.73
# 143  2023  0.87  0.97  1.23  0.99  0.94  1.08  1.19  1.19  1.48  1.34  1.41
# 144  2024  1.24  1.43  1.39  1.31  1.16  1.24   1.2   1.3  1.23  1.33  1.29
# 145  2025  1.36   ***   ***   ***   ***   ***   ***   ***   ***   ***   ***
#
#       Dec
# 0   -0.18
# 1   -0.07
# 2   -0.36
# 3   -0.11
# 4   -0.31
# ..    ...
# 141  0.87
# 142   0.8
# 143  1.36
# 144  1.26
# 145   ***
#
# [146 rows x 13 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 평균 컬럼 추가 (Year 제외한 나머지 열 평균)
df["avg"] = df.iloc[:, 1:].replace("***", float("nan")).astype(float).mean(axis=1)

# 최대값 찾기
max_avg = df["avg"].max()

# 그래프 그리기
plt.figure(figsize=(10, 5))
plt.plot(df["Year"], df["avg"], marker="o", linestyle="-", color="b", label="Avg Temp")

# 최대값에 평행한 빨간색 선 추가
plt.axhline(y=max_avg, color="r", linestyle="--", linewidth=1, label=f"Max Avg ({max_avg:.2f})")

# 그래프 스타일 설정
plt.xlabel("Year")
plt.ylabel("Avg Value")
plt.title("Yearly Average Trend")
plt.legend()
plt.grid(True)

# 그래프 출력
plt.show()

# %%
df.iloc[-20:, :]
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 126  2006  0.56  0.73  0.63  0.46  0.47  0.66  0.54   0.7  0.66  0.69  0.74
# 127  2007  1.02   0.7  0.71  0.76  0.68  0.61  0.59   0.6  0.59  0.58  0.59
# 128  2008  0.30  0.38  0.75  0.54   0.5  0.49   0.6  0.46  0.61  0.67  0.69
# 129  2009  0.64  0.52  0.53  0.61  0.65  0.64  0.74  0.69  0.71  0.65  0.79
# 130  2010  0.74  0.83  0.92  0.85  0.75  0.67  0.63  0.67  0.63  0.72   0.8
# 131  2011  0.52  0.48  0.65  0.64  0.53  0.62   0.7  0.75  0.56  0.65  0.59
# 132  2012  0.47  0.49  0.56  0.72  0.78  0.64  0.58  0.66  0.72   0.8  0.78
# 133  2013  0.71  0.62  0.67  0.53   0.6  0.69   0.6   0.7  0.77  0.69  0.83
# 134  2014  0.76  0.55  0.78   0.8  0.86  0.67  0.58  0.83  0.87   0.8  0.67
# 135  2015  0.86   0.9  0.96  0.75   0.8  0.81  0.73  0.79  0.84  1.07  1.06
# 136  2016  1.18  1.36  1.35  1.09  0.95   0.8  0.84  1.01   0.9  0.87  0.92
# 137  2017  1.02  1.13  1.16  0.94  0.91  0.71  0.81  0.87  0.75  0.89  0.88
# 138  2018  0.82  0.84  0.88  0.88  0.81  0.76  0.83  0.78   0.8  1.01  0.83
# 139  2019  0.93  0.94  1.16   1.0  0.86   0.9  0.93  0.95  0.93  0.99  0.98
# 140  2020  1.17  1.24  1.18  1.12   1.0  0.91  0.89  0.86  0.96  0.87  1.09
# 141  2021  0.81  0.64  0.89  0.75  0.79  0.84  0.91  0.81  0.92  0.98  0.92
# 142  2022  0.91  0.89  1.04  0.83  0.84  0.92  0.94  0.94  0.88  0.96  0.73
# 143  2023  0.87  0.97  1.23  0.99  0.94  1.08  1.19  1.19  1.48  1.34  1.41
# 144  2024  1.24  1.43  1.39  1.31  1.16  1.24   1.2   1.3  1.23  1.33  1.29
# 145  2025  1.36   ***   ***   ***   ***   ***   ***   ***   ***   ***   ***
#
#       Dec
# 126  0.79
# 127  0.49
# 128  0.53
# 129  0.67
# 130  0.45
# 131   0.6
# 132  0.52
# 133   0.7
# 134  0.78
# 135  1.17
# 136  0.86
# 137  0.93
# 138  0.92
# 139  1.11
# 140  0.79
# 141  0.87
# 142   0.8
# 143  1.36
# 144  1.26
# 145   ***

# %%
df.iloc[:,:]['Sep']
# Out:
# 0     -0.15
# 1     -0.16
# 2     -0.14
# 3     -0.22
# 4     -0.27
#        ...
# 140    0.96
# 141    0.92
# 142    0.88
# 143    1.48
# 144    1.23
# Name: Sep, Length: 145, dtype: float64

# %%
values = df.iloc[:,:]['Sep'].values

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[:,:]['Year'], values, marker = 'o', linestyle = '-', color = 'b')
plt.title('-')
plt.xlabel('Year')
plt.ylabel('sep values')
plt.grid(True)
plt.show()
