# %%
# 2024Y 38L updated

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("GLB.Ts+dSST.csv", header =1)
df = df.iloc[:, :13]

# %%
# df.info()

# %%
to_convert = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
       'Oct', 'Nov', 'Dec']

df = df.replace({'***':pd.NA})
df[to_convert] = df[to_convert].apply(pd.to_numeric, errors='coerce')
df = df.fillna('***')
df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.20 -0.26 -0.09 -0.17 -0.10 -0.22 -0.20 -0.11 -0.16 -0.23 -0.23
# 1    1881 -0.20 -0.16  0.02  0.04  0.06 -0.19  0.01 -0.04 -0.16 -0.22 -0.19
# 2    1882  0.16  0.13  0.04 -0.16 -0.14 -0.23 -0.16 -0.08 -0.15 -0.24 -0.17
# 3    1883 -0.29 -0.37 -0.12 -0.18 -0.18 -0.07 -0.07 -0.14 -0.22 -0.12 -0.24
# 4    1884 -0.13 -0.08 -0.36 -0.40 -0.34 -0.35 -0.31 -0.28 -0.27 -0.25 -0.34
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 140  2020  1.18  1.24  1.18  1.12  0.99  0.91  0.89  0.86  0.96  0.87   1.1
# 141  2021  0.81  0.65  0.89  0.76  0.79  0.84  0.92  0.81  0.92  0.99  0.93
# 142  2022  0.91  0.89  1.05  0.83  0.84  0.92  0.94  0.95  0.89  0.97  0.74
# 143  2023  0.88  0.98  1.23  0.99  0.94  1.08  1.19  1.19  1.48  1.34  1.42
# 144  2024  1.25  1.44  1.39  1.32  1.16  1.24  1.20  1.30  1.23  1.32   ***
#
#       Dec
# 0   -0.19
# 1   -0.08
# 2   -0.36
# 3   -0.11
# 4   -0.31
# ..    ...
# 140  0.79
# 141  0.88
# 142   0.8
# 143  1.36
# 144   ***
#
# [145 rows x 13 columns]

# %%
# df.to_csv("glb_temp.csv")

# %%
temp = pd.read_csv('glb_temp.csv')
temp.head(1)
# Out:
#    Unnamed: 0  Year  Jan   Feb   Mar   Apr  May   Jun  Jul   Aug   Sep   Oct  \
# 0           0  1880 -0.2 -0.26 -0.09 -0.17 -0.1 -0.22 -0.2 -0.11 -0.16 -0.23
#
#      Nov    Dec
# 0  -0.23  -0.19

# %%
df.iloc[:,:]['Sep']
# Out:
# 0     -0.16
# 1     -0.16
# 2     -0.15
# 3     -0.22
# 4     -0.27
#        ...
# 140    0.96
# 141    0.92
# 142    0.89
# 143    1.48
# 144    1.23
# Name: Sep, Length: 145, dtype: float64

# %%
values = df.iloc[:-1,:]['Sep'].values

plt.figure(figsize=(10, 5))
plt.plot(df.iloc[:-1,:]['Year'], values, marker = 'o', linestyle = '-', color = 'b')
plt.title('-')
plt.xlabel('Year')
plt.ylabel('sep values')
plt.grid(True)
plt.show()
